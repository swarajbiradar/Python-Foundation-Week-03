# %%
import pandas as pd

data = {
    "Name": ["Swaraj", "Jayed", "Pramod"],
    "Age": [20, 21, 19],
    "Grade": ["A", "B", "A"]
}

df = pd.DataFrame(data)

print("\nStudent DataFrame:")
print(df)
# Out:
# Student DataFrame:
#      Name  Age Grade
# 0  Swaraj   20     A
# 1   Jayed   21     B
# 2  Pramod   19     A
