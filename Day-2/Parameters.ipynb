# %%
import pandas as pd

data = {
    "Name": ["Swaraj", "Jayed", "Pramod"],
    "Marks": [85, 78, 92],
    "City": ["Pune", "Mumbai", "Delhi"]
}

df = pd.DataFrame(data)

print(df)

# Using index_col
df_csv_index = pd.read_csv("students.csv", index_col="Name")

print(df_csv_index)

# Using header
df_header = pd.read_csv("students.csv", header=0)

print(df_header)

# Using sep (custom separator)
df.to_csv("students_pipe.csv", sep="|", index=False)

df_sep = pd.read_csv("students_pipe.csv", sep="|")

print(df_sep)
# Out:
#      Name  Marks    City
# 0  Swaraj     85    Pune
# 1   Jayed     78  Mumbai
# 2  Pramod     92   Delhi
#         Marks    City
# Name
# Swaraj     85    Pune
# Jayed      78  Mumbai
# Pramod     92   Delhi
#      Name  Marks    City
# 0  Swaraj     85    Pune
# 1   Jayed     78  Mumbai
# 2  Pramod     92   Delhi
#      Name  Marks    City
# 0  Swaraj     85    Pune
# 1   Jayed     78  Mumbai
# 2  Pramod     92   Delhi
