# %%
import pandas as pd

sales_data = {
    "Product": ["Laptop", "Phone", "Tablet"],
    "Price": [50000, 20000, 15000],
    "Quantity": [5, 10, 7]
}

sales_df = pd.DataFrame(sales_data)

sales_df.to_csv("sales.csv", index=False)

sales_import = pd.read_csv("sales.csv")

print("Sales Data:")
print(sales_import)
# Out:
# Sales Data:
#   Product  Price  Quantity
# 0  Laptop  50000         5
# 1   Phone  20000        10
# 2  Tablet  15000         7
