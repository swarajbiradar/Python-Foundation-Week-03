# %%
# Real-World Example (Student + Scores)

import pandas as pd

student_info = pd.DataFrame({
    "ID": [1, 2, 3],
    "Name": ["Swaraj", "Jayed", "Pramod"]
})

exam_scores = pd.DataFrame({
    "ID": [1, 2, 3],
    "Score": [88, 92, 85]
})

combined = pd.merge(student_info, exam_scores, on="ID")

print("Combined Data:")
print(combined)
# Out:
# Combined Data:
#    ID    Name  Score
# 0   1  Swaraj     88
# 1   2   Jayed     92
# 2   3  Pramod     85
